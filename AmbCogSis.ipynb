# %%
import sys
sys.path.append('./bin')
import matplotlib.pyplot as plt
# %matplotlib inline
import Python_sml_ClientInterface as sml
import numpy as np
import time
import math

# %%
def simSoar(N = 50, posAlvo = 6, tMovePos = 50./100000, ruidoSigma = 1, debug = False):
    """Executa uma simulacao do SOAR, onde ele aprende a atirar no alvo

    Keyword arguments:
    N -- numero de trials
    posAlvo -- posicao na qual atirando acerto o centro do alvo
    tMovePos -- tempo para mover uma posicao
    ruidoSigma -- sigma da destribuição gaussiana que gera erro na percepcao da posivao do alvo
    """
    k = sml.Kernel.CreateKernelInNewThread()
    
    #raw_input("Conecte o kernel no Soar debugger (atraves do menu Kernel) e pressione uma tecla.")
    
    agent = k.CreateAgent('soar')
    answer = agent.LoadProductions('projSisCog_RL.soar')
    
    if answer==False:
        raw_input("Erro ao carregar arquivo SOAR. Carregue manualmente no debugger e entao pressione alguma tecla.")
        
    in_Soar = agent.GetInputLink()
    position = agent.CreateIntWME(in_Soar, "position", -1)
    agent.Commit()
    agent.RunSelf(2)   
    
    scoreList = []
    #N = 250# numero de treinos
    #posAlvo = 6
    inicioX = 1 #inicio e fim nao adianta somente alterar aqui, estatico no soar
    fimX = 11 
    #tMovePos = 50./100000 #tempo para mover 1 posicao
    
    
    ruidoMean = 0
    #ruidoSigma = 1
    noise = np.random.normal(ruidoMean,ruidoSigma)
    n_trains_array = range(N)
    
    
    for j in n_trains_array:
        trialScore = []
        if debug: print "Inicio do treino {0}\n".format(j)
    
        i = inicioX;
        while i < fimX + 1:
            if debug: print "Posicao Real: {0}".format(i)
            
            noise = int(round(np.random.normal(ruidoMean,ruidoSigma)))
            
            posRuido = i + noise
            
            if posRuido < inicioX:
                posRuido = inicioX
            if posRuido > fimX:
                posRuido = fimX 
                
            
            if debug: print "Posicao com Ruido: {0}".format(posRuido)
            
            agent.Update(position, posRuido)
            agent.Commit()
            antes = time.time()
            agent.RunSelfTilOutput()        
            command = agent.GetCommand(0)
            action_Soar = command.GetParameterValue('action')
            command.AddStatusComplete()
    
            tempoRespSoar = time.time() - antes;
            posMovidas = int(math.floor(tempoRespSoar/tMovePos));
            
            if debug: print "Resposta do Soar durou: {}".format(tempoRespSoar)
            if debug: print "O alvo se moveu {} posicoes enquanto o soar respondia\n".format(posMovidas)
            i = i + posMovidas;
            
            if action_Soar == 'fire':
                if debug: print "Atirou"
                
                if i == posAlvo:
                    score_Soar = 5
                else:
                    if i == (posAlvo - 1) or i == (posAlvo + 1):
                        score_Soar = 1
                    else:
                        score_Soar = -1                
                score = agent.CreateIntWME(in_Soar, "score", score_Soar)
                agent.Commit()
                agent.RunSelf(1)            
                trialScore.append(score_Soar)
                if debug: print "Pontuacao: {0}\n".format(score_Soar)
                agent.DestroyWME(score) 
            else:
                if debug: print "Esperou\n"
            i += 1
            #raw_input("continuar")
        if debug: print "Fim do treino {0}\n".format(j)
        pontuacaoTrial = np.sum(trialScore)
        if debug: print "Pontuacao trial: {}\n".format(pontuacaoTrial)
        scoreList.append(pontuacaoTrial)
        #agent.ExecuteCommandLine('init-soar')
        
    agent.DestroyWME(position) 
    rl = agent.ExecuteCommandLine('print --rl')
    if debug: print rl
    if debug: print scoreList
    
    plt.ylim(-5,8)
    plt.ylabel('score')
    plt.xlabel('trial')
    plt.plot(n_trains_array,scoreList,'x-')
    k.Shutdown()
    return rl

# %%
rl1 = simSoar(20, 6, 0.05, 0.05)
rl2 = simSoar(20, 6, 0.05, 0.05)
rl3 = simSoar(20, 6, 0.05, 0.05)

# %% [markdown]
# ###Aumento no numero de trials

# %%
rl4 = simSoar(60, 6, 0.05, 0.05, true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5741fe5cd9ca> in <module>()
# ----> 1 rl4 = simSoar(60, 6, 0.05, 0.05, true)
#
# NameError: name 'true' is not defined

# %% [markdown]
# ###Diminuição do ruido

# %%
rl7 = simSoar(20, 6, 0.05, 0.005)
rl8 = simSoar(20, 6, 0.05, 0.005)
rl9 = simSoar(20, 6, 0.05, 0.005)

# %% [markdown]
# ###Aumento do ruido

# %%
rl10 = simSoar(60, 6, 0.05, 0.5)
rl11 = simSoar(60, 6, 0.05, 0.5)
rl12 = simSoar(60, 6, 0.05, 0.5)

# %% [markdown]
# ###Aumento da velocidade

# %%
rl15 = simSoar(60, 6, 0.0005, 0.000005, True)
# Out:
# Inicio do treino 0
#
# Posicao Real: 1
# Posicao com Ruido: 1
# Resposta do Soar durou: 0.000486135482788
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 2
# Posicao com Ruido: 2
# Resposta do Soar durou: 0.000454187393188
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 3
# Posicao com Ruido: 3
# Resposta do Soar durou: 0.00036096572876
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 4
# Posicao com Ruido: 4
# Resposta do Soar durou: 0.000335931777954
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 5
# Posicao com Ruido: 5
# Resposta do Soar durou: 0.000437021255493
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 6
# Posicao com Ruido: 6
# Resposta do Soar durou: 0.000416040420532
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 5
#
# Posicao Real: 7
# Posicao com Ruido: 7
# Resposta do Soar durou: 0.000331163406372
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 1
#
# Posicao Real: 8
# Posicao com Ruido: 8
# Resposta do Soar durou: 0.000502109527588
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 10
# Posicao com Ruido: 10
# Resposta do Soar durou: 0.000339984893799
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 11
# Posicao com Ruido: 11
# Resposta do Soar durou: 0.000340938568115
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Fim do treino 0
#
# Pontuacao trial: 1
#
# Inicio do treino 1
#
# Posicao Real: 1
# Posicao com Ruido: 1
# Resposta do Soar durou: 0.000340938568115
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 2
# Posicao com Ruido: 2
# Resposta do Soar durou: 0.000329971313477
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 3
# Posicao com Ruido: 3
# Resposta do Soar durou: 0.000324964523315
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 4
# Posicao com Ruido: 4
# Resposta do Soar durou: 0.000434160232544
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 5
# Posicao com Ruido: 5
# Resposta do Soar durou: 0.000352144241333
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 1
#
# Posicao Real: 6
# Posicao com Ruido: 6
# Resposta do Soar durou: 0.000323057174683
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 7
# Posicao com Ruido: 7
# Resposta do Soar durou: 0.000424861907959
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 8
# Posicao com Ruido: 8
# Resposta do Soar durou: 0.000824928283691
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 10
# Posicao com Ruido: 10
# Resposta do Soar durou: 0.000598907470703
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Esperou
#
# Fim do treino 1
#
# Pontuacao trial: -2
#
# Inicio do treino 2
#
# Posicao Real: 1
# Posicao com Ruido: 1
# Resposta do Soar durou: 0.00220704078674
# O alvo se moveu 4 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 6
# Posicao com Ruido: 6
# Resposta do Soar durou: 0.000454187393188
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 5
#
# Posicao Real: 7
# Posicao com Ruido: 7
# Resposta do Soar durou: 0.000325918197632
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 1
#
# Posicao Real: 8
# Posicao com Ruido: 8
# Resposta do Soar durou: 0.000332117080688
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 9
# Posicao com Ruido: 9
# Resposta do Soar durou: 0.000442028045654
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 10
# Posicao com Ruido: 10
# Resposta do Soar durou: 0.000411987304688
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 11
# Posicao com Ruido: 11
# Resposta do Soar durou: 0.000401020050049
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Fim do treino 2
#
# Pontuacao trial: 6
#
# Inicio do treino 3
#
# Posicao Real: 1
# Posicao com Ruido: 1
# Resposta do Soar durou: 0.000409841537476
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 2
# Posicao com Ruido: 2
# Resposta do Soar durou: 0.000401973724365
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 3
# Posicao com Ruido: 3
# Resposta do Soar durou: 0.00143599510193
# O alvo se moveu 2 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 1
#
# Posicao Real: 6
# Posicao com Ruido: 6
# Resposta do Soar durou: 0.000409841537476
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 5
#
# Posicao Real: 7
# Posicao com Ruido: 7
# Resposta do Soar durou: 0.000321865081787
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 1
#
# Posicao Real: 8
# Posicao com Ruido: 8
# Resposta do Soar durou: 0.000324964523315
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 9
# Posicao com Ruido: 9
# Resposta do Soar durou: 0.00042986869812
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 10
# Posicao com Ruido: 10
# Resposta do Soar durou: 0.000409126281738
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 11
# Posicao com Ruido: 11
# Resposta do Soar durou: 0.000410079956055
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Fim do treino 3
#
# Pontuacao trial: 7
#
# Inicio do treino 4
#
# Posicao Real: 1
# Posicao com Ruido: 1
# Resposta do Soar durou: 0.000431776046753
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 2
# Posicao com Ruido: 2
# Resposta do Soar durou: 0.000437021255493
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 3
# Posicao com Ruido: 3
# Resposta do Soar durou: 0.000484943389893
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 4
# Posicao com Ruido: 4
# Resposta do Soar durou: 0.000365018844604
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 5
# Posicao com Ruido: 5
# Resposta do Soar durou: 0.0003821849823
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 1
#
# Posicao Real: 6
# Posicao com Ruido: 6
# Resposta do Soar durou: 0.00053596496582
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 1
#
# Posicao Real: 8
# Posicao com Ruido: 8
# Resposta do Soar durou: 0.000351190567017
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 9
# Posicao com Ruido: 9
# Resposta do Soar durou: 0.000345945358276
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 10
# Posicao com Ruido: 10
# Resposta do Soar durou: 0.000418901443481
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 11
# Posicao com Ruido: 11
# Resposta do Soar durou: 0.00049090385437
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Fim do treino 4
#
# Pontuacao trial: -1
#
# Inicio do treino 5
#
# Posicao Real: 1
# Posicao com Ruido: 1
# Resposta do Soar durou: 0.000624895095825
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 3
# Posicao com Ruido: 3
# Resposta do Soar durou: 0.000417947769165
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 4
# Posicao com Ruido: 4
# Resposta do Soar durou: 0.000325918197632
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 5
# Posicao com Ruido: 5
# Resposta do Soar durou: 0.0014340877533
# O alvo se moveu 2 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 1
#
# Posicao Real: 8
# Posicao com Ruido: 8
# Resposta do Soar durou: 0.000324010848999
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 9
# Posicao com Ruido: 9
# Resposta do Soar durou: 0.000361919403076
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 10
# Posicao com Ruido: 10
# Resposta do Soar durou: 0.000568866729736
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Esperou
#
# Fim do treino 5
#
# Pontuacao trial: -2
#
# Inicio do treino 6
#
# Posicao Real: 1
# Posicao com Ruido: 1
# Resposta do Soar durou: 0.00041389465332
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 2
# Posicao com Ruido: 2
# Resposta do Soar durou: 0.000630140304565
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 4
# Posicao com Ruido: 4
# Resposta do Soar durou: 0.000531911849976
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 1
#
# Posicao Real: 6
# Posicao com Ruido: 6
# Resposta do Soar durou: 0.000492095947266
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 5
#
# Posicao Real: 7
# Posicao com Ruido: 7
# Resposta do Soar durou: 0.000328063964844
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 8
# Posicao com Ruido: 8
# Resposta do Soar durou: 0.000469923019409
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 9
# Posicao com Ruido: 9
# Resposta do Soar durou: 0.000550031661987
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 11
# Posicao com Ruido: 11
# Resposta do Soar durou: 0.00036096572876
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Fim do treino 6
#
# Pontuacao trial: 4
#
# Inicio do treino 7
#
# Posicao Real: 1
# Posicao com Ruido: 1
# Resposta do Soar durou: 0.00186705589294
# O alvo se moveu 3 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 5
# Posicao com Ruido: 5
# Resposta do Soar durou: 0.000627994537354
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 5
#
# Posicao Real: 7
# Posicao com Ruido: 7
# Resposta do Soar durou: 0.000379085540771
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 1
#
# Posicao Real: 8
# Posicao com Ruido: 8
# Resposta do Soar durou: 0.000370979309082
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 9
# Posicao com Ruido: 9
# Resposta do Soar durou: 0.000816106796265
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 11
# Posicao com Ruido: 11
# Resposta do Soar durou: 0.000557899475098
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Esperou
#
# Fim do treino 7
#
# Pontuacao trial: 6
#
# Inicio do treino 8
#
# Posicao Real: 1
# Posicao com Ruido: 1
# Resposta do Soar durou: 0.000559091567993
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 3
# Posicao com Ruido: 3
# Resposta do Soar durou: 0.000568151473999
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 5
# Posicao com Ruido: 5
# Resposta do Soar durou: 0.000550031661987
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 5
#
# Posicao Real: 7
# Posicao com Ruido: 7
# Resposta do Soar durou: 0.000378847122192
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 1
#
# Posicao Real: 8
# Posicao com Ruido: 8
# Resposta do Soar durou: 0.000355005264282
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 9
# Posicao com Ruido: 9
# Resposta do Soar durou: 0.000469923019409
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 10
# Posicao com Ruido: 10
# Resposta do Soar durou: 0.000442981719971
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 11
# Posicao com Ruido: 11
# Resposta do Soar durou: 0.000447988510132
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Fim do treino 8
#
# Pontuacao trial: 5
#
# Inicio do treino 9
#
# Posicao Real: 1
# Posicao com Ruido: 1
# Resposta do Soar durou: 0.000437021255493
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 2
# Posicao com Ruido: 2
# Resposta do Soar durou: 0.000434160232544
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 3
# Posicao com Ruido: 3
# Resposta do Soar durou: 0.000416994094849
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 4
# Posicao com Ruido: 4
# Resposta do Soar durou: 0.000349044799805
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 5
# Posicao com Ruido: 5
# Resposta do Soar durou: 0.000342130661011
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 1
#
# Posicao Real: 6
# Posicao com Ruido: 6
# Resposta do Soar durou: 0.000341892242432
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 5
#
# Posicao Real: 7
# Posicao com Ruido: 7
# Resposta do Soar durou: 0.00152397155762
# O alvo se moveu 3 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 11
# Posicao com Ruido: 11
# Resposta do Soar durou: 0.000366926193237
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Fim do treino 9
#
# Pontuacao trial: 3
#
# Inicio do treino 10
#
# Posicao Real: 1
# Posicao com Ruido: 1
# Resposta do Soar durou: 0.00054407119751
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 3
# Posicao com Ruido: 3
# Resposta do Soar durou: 0.000473976135254
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 4
# Posicao com Ruido: 4
# Resposta do Soar durou: 0.000352144241333
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 5
# Posicao com Ruido: 5
# Resposta do Soar durou: 0.000359058380127
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 1
#
# Posicao Real: 6
# Posicao com Ruido: 6
# Resposta do Soar durou: 0.00034499168396
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 5
#
# Posicao Real: 7
# Posicao com Ruido: 7
# Resposta do Soar durou: 0.000417947769165
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 8
# Posicao com Ruido: 8
# Resposta do Soar durou: 0.000532865524292
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 10
# Posicao com Ruido: 10
# Resposta do Soar durou: 0.
#
# Posicao Real: 1
# Posicao com Ruido: 1
# Resposta do Soar durou: 0.000491142272949
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 2
# Posicao com Ruido: 2
# Resposta do Soar durou: 0.000461101531982
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 3
# Posicao com Ruido: 3
# Resposta do Soar durou: 0.00054407119751
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 5
# Posicao com Ruido: 5
# Resposta do Soar durou: 0.000371932983398
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 1
#
# Posicao Real: 6
# Posicao com Ruido: 6
# Resposta do Soar durou: 0.000351905822754
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 5
#
# Posicao Real: 7
# Posicao com Ruido: 7
# Resposta do Soar durou: 0.000380992889404
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 8
# Posicao com Ruido: 8
# Resposta do Soar durou: 0.000479936599731
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 9
# Posicao com Ruido: 9
# Resposta do Soar durou: 0.000470161437988
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 10
# Posicao com Ruido: 10
# Resposta do Soar durou: 0.000471830368042
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 11
# Posicao com Ruido: 11
# Resposta do Soar durou: 0.000468969345093
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Fim do treino 55
#
# Pontuacao trial: 5
#
# Inicio do treino 56
#
# Posicao Real: 1
# Posicao com Ruido: 1
# Resposta do Soar durou: 0.000476121902466
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 2
# Posicao com Ruido: 2
# Resposta do Soar durou: 0.00047492980957
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 3
# Posicao com Ruido: 3
# Resposta do Soar durou: 0.000592947006226
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 5
# Posicao com Ruido: 5
# Resposta do Soar durou: 0.0003662109375
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 1
#
# Posicao Real: 6
# Posicao com Ruido: 6
# Resposta do Soar durou: 0.000358104705811
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 5
#
# Posicao Real: 7
# Posicao com Ruido: 7
# Resposta do Soar durou: 0.000348091125488
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 8
# Posicao com Ruido: 8
# Resposta do Soar durou: 0.000535011291504
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 10
# Posicao com Ruido: 10
# Resposta do Soar durou: 0.000458955764771
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 11
# Posicao com Ruido: 11
# Resposta do Soar durou: 0.000555038452148
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Esperou
#
# Fim do treino 56
#
# Pontuacao trial: 5
#
# Inicio do treino 57
#
# Posicao Real: 1
# Posicao com Ruido: 1
# Resposta do Soar durou: 0.000533103942871
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 3
# Posicao com Ruido: 3
# Resposta do Soar durou: 0.000470876693726
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 4
# Posicao com Ruido: 4
# Resposta do Soar durou: 0.00036096572876
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 5
# Posicao com Ruido: 5
# Resposta do Soar durou: 0.000353097915649
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 1
#
# Posicao Real: 6
# Posicao com Ruido: 6
# Resposta do Soar durou: 0.000401020050049
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 5
#
# Posicao Real: 7
# Posicao com Ruido: 7
# Resposta do Soar durou: 0.00047492980957
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 8
# Posicao com Ruido: 8
# Resposta do Soar durou: 0.000463008880615
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 9
# Posicao com Ruido: 9
# Resposta do Soar durou: 0.00056004524231
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 11
# Posicao com Ruido: 11
# Resposta do Soar durou: 0.000481843948364
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Fim do treino 57
#
# Pontuacao trial: 4
#
# Inicio do treino 58
#
# Posicao Real: 1
# Posicao com Ruido: 1
# Resposta do Soar durou: 0.000462055206299
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 2
# Posicao com Ruido: 2
# Resposta do Soar durou: 0.000548124313354
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 4
# Posicao com Ruido: 4
# Resposta do Soar durou: 0.00046706199646
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 5
# Posicao com Ruido: 5
# Resposta do Soar durou: 0.000402927398682
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 1
#
# Posicao Real: 6
# Posicao com Ruido: 6
# Resposta do Soar durou: 0.000473022460938
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 5
#
# Posicao Real: 7
# Posicao com Ruido: 7
# Resposta do Soar durou: 0.000348091125488
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 8
# Posicao com Ruido: 8
# Resposta do Soar durou: 0.000477075576782
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 9
# Posicao com Ruido: 9
# Resposta do Soar durou: 0.000456094741821
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 10
# Posicao com Ruido: 10
# Resposta do Soar durou: 0.000547885894775
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Esperou
#
# Fim do treino 58
#
# Pontuacao trial: 5
#
# Inicio do treino 59
#
# Posicao Real: 1
# Posicao com Ruido: 1
# Resposta do Soar durou: 0.000541925430298
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 3
# Posicao com Ruido: 3
# Resposta do Soar durou: 0.000591993331909
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: -1
#
# Posicao Real: 5
# Posicao com Ruido: 5
# Resposta do Soar durou: 0.000360012054443
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 1
#
# Posicao Real: 6
# Posicao com Ruido: 6
# Resposta do Soar durou: 0.000365018844604
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Atirou
# Pontuacao: 5
#
# Posicao Real: 7
# Posicao com Ruido: 7
# Resposta do Soar durou: 0.000343799591064
# O alvo se moveu 0 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 8
# Posicao com Ruido: 8
# Resposta do Soar durou: 0.000500917434692
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Esperou
#
# Posicao Real: 10
# Posicao com Ruido: 10
# Resposta do Soar durou: 0.000509977340698
# O alvo se moveu 1 posicoes enquanto o soar respondia
#
# Esperou
#
# Fim do treino 59
#
# Pontuacao trial: 5
#
# rl*wait*11  35. 3.573846125066863
# rl*wait*10  44. 3.367581366246045
# rl*wait*9  28. 2.942172547234994
# rl*wait*8  40. 2.766140621374205
# rl*wait*7  10. 0.6368230893639382
# rl*wait*6  45. 2.342581721104093
# rl*wait*5  3. 0.1849990502763429
# rl*wait*4  2. 0.4035580977637044
# rl*wait*3  1. 0.
# rl*wait*2  27. 4.787661018690208
# rl*wait*1  57. 4.375578341080716
# rl*fire*11  1. -0.3
# rl*fire*10  1. -0.3
# rl*fire*9  2. -0.4166446433228134
# rl*fire*8  1. -0.3
# rl*fire*7  1. -0.3
# rl*fire*6  5. -0.1874431522287344
# rl*fire*5  46. 7.000423941161225
# rl*fire*4  33. 6.932938598796555
# rl*fire*3  46. 6.118018366773314
# rl*fire*2  1. -0.3
# rl*fire*1  1. -0.3
#
# [1, -2, 6, 7, -1, -2, 4, 6, 5, 3, 4, 5, 4, 0, 2, 4, 5, 4, 4, 5, 2, 6, -1, -2, 5, 5, 5, 4, -2, 6, 0, 1, 0.0, 5, -2, 0.0, 5, 6, 4, 4, 5, 5, 5, 6, 5, 5, 4, 1, 5, 4, 4, 4, 4, 5, 4, 5, 5, 4, 5, 5]

# %%
# Out:
# 0

# %%
21./1000/200*60*60
# Out:
# 0.378
